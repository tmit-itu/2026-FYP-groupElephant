# %%
import pandas as pd

baseline = pd.read_csv("../results/features_baseline.csv")
baseline
# Out:
#                      img_id patient_id  cancer  asymmetry    border  \
# 0     PAT_1549_1882_230.png   PAT_1549       0   0.074175  1.160264
# 1      PAT_636_1204_521.png    PAT_636       1   0.163275  1.767430
# 2      PAT_778_1471_835.png    PAT_778       1   0.114550  1.146527
# 3     PAT_1545_1867_547.png   PAT_1545       0   0.165250  1.595825
# 4      PAT_684_1302_588.png    PAT_684       1   0.118025  1.195607
# ...                     ...        ...     ...        ...       ...
# 2098    PAT_279_430_356.png    PAT_279       0   0.116325  1.190750
# 2099   PAT_739_1398_331.png    PAT_739       0   0.237125  1.284300
# 2100    PAT_192_884_310.png    PAT_192       0   0.793400  2.761158
# 2101     PAT_46_880_140.png     PAT_46       1   0.138125  1.352481
# 2102   PAT_754_1429_380.png    PAT_754       1   0.124050  1.224961
#
#          texture    h_mean    s_mean    v_mean     h_std     s_std     v_std  \
# ...

# %%
extended = pd.read_csv("../results/features_extended.csv")
extended
# Out:
#                      img_id patient_id  hair_coverage  cancer  asymmetry  \
# 0     PAT_1549_1882_230.png   PAT_1549       0.532986       0   0.074175
# 1      PAT_778_1471_835.png    PAT_778       0.676240       1   0.114550
# 2     PAT_1545_1867_547.png   PAT_1545       0.199202       0   0.165250
# 3      PAT_636_1204_521.png    PAT_636       0.263348       1   0.163275
# 4      PAT_684_1302_588.png    PAT_684       0.042157       1   0.118025
# ...                     ...        ...            ...     ...        ...
# 2098    PAT_279_430_356.png    PAT_279       0.349638       0   0.116325
# 2099    PAT_192_884_310.png    PAT_192       0.018358       0   0.793400
# 2100     PAT_46_880_140.png     PAT_46       0.006873       1   0.138125
# 2101   PAT_2140_4726_85.png   PAT_2140       0.449052       0   0.317350
# 2102   PAT_754_1429_380.png    PAT_754       0.007678       1   0.124050
#
#         border     texture    h_mean    s_mean    v_mean     h_std     s_std  \
# ...
